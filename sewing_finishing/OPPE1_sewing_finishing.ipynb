# %% [markdown]
# # V5.

# %%
import numpy as np
import pandas as pd

# %%
df =  pd.read_csv('/content/oppe1_sewing_finishing.csv')
df
# Out:
#           date  department  team  targeted_productivity    smv     wip  \
# 0    2/28/2015   finishing     9                   0.75   2.90     NaN
# 1    2/23/2015   finishing     8                   0.70   5.13     NaN
# 2     1/1/2015      sweing    10                   0.75  19.31   578.0
# 3    1/13/2015      sweing     5                   0.70  20.79  1297.0
# 4     2/2/2015  finishing      6                   0.60   2.90     NaN
# ..         ...         ...   ...                    ...    ...     ...
# 995  2/14/2015   finishing     9                   0.80   3.94     NaN
# 996  2/19/2015      sweing     1                   0.80  22.52   265.0
# 997  1/17/2015  finishing      8                   0.80   2.90     NaN
# 998  1/15/2015  finishing      9                   0.80   3.94     NaN
# 999  1/14/2015      sweing     5                   0.70  20.79   965.0
#
#      over_time  incentive  idle_time  idle_men  no_of_style_change  \
# ...

# %% [markdown]
# ## Q2.

# %%
df.shape
# Out:
# (1000, 13)

# %% [markdown]
# ## Q5.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1000 non-null   object
#  1   department             1000 non-null   object
#  2   team                   1000 non-null   int64
#  3   targeted_productivity  1000 non-null   float64
#  4   smv                    1000 non-null   float64
#  5   wip                    571 non-null    float64
#  6   over_time              1000 non-null   int64
#  7   incentive              1000 non-null   int64
#  8   idle_time              1000 non-null   float64
#  9   idle_men               1000 non-null   int64
#  10  no_of_style_change     1000 non-null   int64
#  11  no_of_workers          1000 non-null   float64
#  12  actual_productivity    1000 non-null   float64
# dtypes: float64(6), int64(5), object(2)
# memory usage: 101.7+ KB

# %% [markdown]
# ## Q3.

# %%
df.isnull().sum()
# Out:
# date                       0
# department                 0
# team                       0
# targeted_productivity      0
# smv                        0
# wip                      429
# over_time                  0
# incentive                  0
# idle_time                  0
# idle_men                   0
# no_of_style_change         0
# no_of_workers              0
# actual_productivity        0
# dtype: int64

# %% [markdown]
# ## Q4.

# %%
df['department'].unique()
# Out:
# array(['finishing', 'sweing', 'finishing '], dtype=object)

# %%
df['wip'].replace(np.nan,0,inplace=True)

# %%
df.isnull().sum()
# Out:
# date                     0
# department               0
# team                     0
# targeted_productivity    0
# smv                      0
# wip                      0
# over_time                0
# incentive                0
# idle_time                0
# idle_men                 0
# no_of_style_change       0
# no_of_workers            0
# actual_productivity      0
# dtype: int64

# %% [markdown]
# ## Q6.

# %%
len(df[df['incentive']>1000])
# Out:
# 3

# %%
x = df.drop(['actual_productivity'], axis=1)
x
# Out:
#           date  department  team  targeted_productivity    smv     wip  \
# 0    2/28/2015   finishing     9                   0.75   2.90     0.0
# 1    2/23/2015   finishing     8                   0.70   5.13     0.0
# 2     1/1/2015      sweing    10                   0.75  19.31   578.0
# 3    1/13/2015      sweing     5                   0.70  20.79  1297.0
# 4     2/2/2015  finishing      6                   0.60   2.90     0.0
# ..         ...         ...   ...                    ...    ...     ...
# 995  2/14/2015   finishing     9                   0.80   3.94     0.0
# 996  2/19/2015      sweing     1                   0.80  22.52   265.0
# 997  1/17/2015  finishing      8                   0.80   2.90     0.0
# 998  1/15/2015  finishing      9                   0.80   3.94     0.0
# 999  1/14/2015      sweing     5                   0.70  20.79   965.0
#
#      over_time  incentive  idle_time  idle_men  no_of_style_change  \
# ...

# %%
y = df['actual_productivity']

# %%
y
# Out:
# 0      0.407813
# 1      0.930417
# 2      0.712205
# 3      0.526810
# 4      0.280333
#          ...
# 995    0.238042
# 996    0.800471
# 997    0.675568
# 998    0.858144
# 999    0.700096
# Name: actual_productivity, Length: 1000, dtype: float64

# %% [markdown]
# ## Q7.

# %%
np.mean(y)
# Out:
# 0.738865622956

# %% [markdown]
# ## Q8.

# %%
import seaborn as sns
sns.heatmap(df.iloc[:,2:].corr(),annot=True)
# Out:
# <Axes: >

# %%
df.corr()
# Out:
# <ipython-input-18-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                            team  targeted_productivity       smv       wip  \
# team                   1.000000               0.047730 -0.086640  0.006885
# targeted_productivity  0.047730               1.000000 -0.086332  0.016236
# smv                   -0.086640              -0.086332  1.000000  0.332743
# wip                    0.006885               0.016236  0.332743  1.000000
# over_time             -0.074047              -0.070017  0.691550  0.291543
# incentive             -0.010981               0.013127  0.040561  0.044056
# idle_time              0.005853              -0.062446  0.062238 -0.005067
# idle_men               0.047636              -0.042299  0.108294 -0.002482
# ...

# %% [markdown]
# ### Common Instructions for Question 9 and 10
#
# #Step 1: Drop the date column from X data.
#
# #Step 2: We can see in "department" column  wrong spelling of "Sweing" is given. Update it to "Sewing" in X dataset.
#
# #Step 3: At some places in "department" column "finishing" variable is written with an extra space So, replace "finishing " with "finishing" in X dataset.
#
# #Step 4 Use pd.getdummies to encode all  categorical features of X dataset.

# %%
x.drop(['date'], axis=1, inplace=True)
x
# Out:
#      department  team  targeted_productivity    smv     wip  over_time  \
# 0     finishing     9                   0.75   2.90     0.0        960
# 1     finishing     8                   0.70   5.13     0.0        960
# 2        sweing    10                   0.75  19.31   578.0       6480
# 3        sweing     5                   0.70  20.79  1297.0      10440
# 4    finishing      6                   0.60   2.90     0.0       1200
# ..          ...   ...                    ...    ...     ...        ...
# 995   finishing     9                   0.80   3.94     0.0        960
# 996      sweing     1                   0.80  22.52   265.0       3840
# 997  finishing      8                   0.80   2.90     0.0       1440
# 998  finishing      9                   0.80   3.94     0.0       1440
# 999      sweing     5                   0.70  20.79   965.0       7320
#
#      incentive  idle_time  idle_men  no_of_style_change  no_of_workers
# ...

# %%
x['department'].replace('sweing','sewing', inplace=True)
x
# Out:
#      department  team  targeted_productivity    smv     wip  over_time  \
# 0     finishing     9                   0.75   2.90     0.0        960
# 1     finishing     8                   0.70   5.13     0.0        960
# 2        sewing    10                   0.75  19.31   578.0       6480
# 3        sewing     5                   0.70  20.79  1297.0      10440
# 4    finishing      6                   0.60   2.90     0.0       1200
# ..          ...   ...                    ...    ...     ...        ...
# 995   finishing     9                   0.80   3.94     0.0        960
# 996      sewing     1                   0.80  22.52   265.0       3840
# 997  finishing      8                   0.80   2.90     0.0       1440
# 998  finishing      9                   0.80   3.94     0.0       1440
# 999      sewing     5                   0.70  20.79   965.0       7320
#
#      incentive  idle_time  idle_men  no_of_style_change  no_of_workers
# ...

# %%
x['department'].replace('finishing ','finishing', inplace=True)
x
# Out:
#     department  team  targeted_productivity    smv     wip  over_time  \
# 0    finishing     9                   0.75   2.90     0.0        960
# 1    finishing     8                   0.70   5.13     0.0        960
# 2       sewing    10                   0.75  19.31   578.0       6480
# 3       sewing     5                   0.70  20.79  1297.0      10440
# 4    finishing     6                   0.60   2.90     0.0       1200
# ..         ...   ...                    ...    ...     ...        ...
# 995  finishing     9                   0.80   3.94     0.0        960
# 996     sewing     1                   0.80  22.52   265.0       3840
# 997  finishing     8                   0.80   2.90     0.0       1440
# 998  finishing     9                   0.80   3.94     0.0       1440
# 999     sewing     5                   0.70  20.79   965.0       7320
#
#      incentive  idle_time  idle_men  no_of_style_change  no_of_workers
# ...

# %%
x['department'].unique()
# Out:
# array(['finishing', 'sewing'], dtype=object)

# %%
dummy = pd.get_dummies(x['department'])
dummy
# Out:
#      finishing  sewing
# 0            1       0
# 1            1       0
# 2            0       1
# 3            0       1
# 4            1       0
# ..         ...     ...
# 995          1       0
# 996          0       1
# 997          1       0
# 998          1       0
# 999          0       1
#
# [1000 rows x 2 columns]

# %%
x['finishing'] = dummy['finishing']
x['sewing'] = dummy['sewing']
x.drop(['department'], axis=True,inplace=True)

# %%
x
# Out:
#      team  targeted_productivity    smv     wip  over_time  incentive  \
# 0       9                   0.75   2.90     0.0        960          0
# 1       8                   0.70   5.13     0.0        960          0
# 2      10                   0.75  19.31   578.0       6480         45
# 3       5                   0.70  20.79  1297.0      10440          0
# 4       6                   0.60   2.90     0.0       1200          0
# ..    ...                    ...    ...     ...        ...        ...
# 995     9                   0.80   3.94     0.0        960          0
# 996     1                   0.80  22.52   265.0       3840         63
# 997     8                   0.80   2.90     0.0       1440          0
# 998     9                   0.80   3.94     0.0       1440          0
# 999     5                   0.70  20.79   965.0       7320          0
#
#      idle_time  idle_men  no_of_style_change  no_of_workers  finishing  sewing
# ...

# %% [markdown]
# ## Q10.

# %%
x.shape
# Out:
# (1000, 12)

# %% [markdown]
# ## Q9.

# %%
sum(x['finishing'])
# Out:
# 429

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size = 0.3, random_state = 32)

# %% [markdown]
# ## Q11.

# %%
X_train.shape
# Out:
# (700, 12)

# %%
X_train
# Out:
#      team  targeted_productivity    smv     wip  over_time  incentive  \
# 111    11                   0.80   4.15     0.0       1440          0
# 153     8                   0.75  29.40   916.0       6960         56
# 614    12                   0.80   4.60     0.0       1080          0
# 313     9                   0.80  26.16  1232.0      10620         75
# 346     1                   0.80  22.52  1546.0          0         88
# ..    ...                    ...    ...     ...        ...        ...
# 892     7                   0.50   3.90     0.0        960          0
# 310     1                   0.80  48.68   171.0      10620         63
# 901     9                   0.50  29.12   970.0      10440         30
# 555     4                   0.60   3.94     0.0        960          0
# 727    10                   0.60  18.22  1131.0       5280          0
#
#      idle_time  idle_men  no_of_style_change  no_of_workers  finishing  sewing
# ...

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

# %%
pred = lr.predict(X_test)

# %% [markdown]
# ## Q12.

# %%
r2_score(y_test, pred)
# Out:
# 0.2501423043398864

# %%
from sklearn.model_selection import cross_val_score
cvs = cross_val_score(lr, X_train, y_train, cv=9, scoring='r2')
cvs
# Out:
# array([ 0.29471012,  0.28179335,  0.3806599 ,  0.03887108,  0.19811357,
#         0.29920051,  0.19853387, -0.15346939,  0.39192951])

# %% [markdown]
# ## Q13.

# %%
np.round(max(cvs),4)
# Out:
# 0.3919

# %%
from sklearn.feature_selection import SequentialFeatureSelector

# %% [markdown]
# ## Q14.

# %%
sfs = SequentialFeatureSelector(lr, n_features_to_select=5)
sfs.fit(X_train, y_train)
sfs.get_support()
# Out:
# array([ True,  True, False,  True, False, False, False,  True,  True,
#        False, False, False])

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_regression

# %%
X_new = SelectKBest(mutual_info_regression, k=5)
X_new.fit(X_train, y_train)
# Out:
# SelectKBest(k=5, score_func=<function mutual_info_regression at 0x7e07105bd000>)

# %% [markdown]
# ## Q15.

# %%
X_new.get_feature_names_out()
# Out:
# array(['targeted_productivity', 'smv', 'over_time', 'incentive',
#        'no_of_workers'], dtype=object)

# %%
from sklearn.linear_model import Ridge
rid = Ridge()

# %%
rid.fit(X_train,y_train)
# Out:
# Ridge()

# %% [markdown]
# ## Q16.

# %%
rid.score(X_train,y_train)
# Out:
# 0.2708570999623262

# %%
from sklearn.linear_model import Lasso
ls = Lasso(alpha=0.1)
ls.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.1)

# %% [markdown]
# ## Q17.

# %%
np.round(ls.intercept_,4)
# Out:
# 0.7544

# %%
from sklearn.linear_model import SGDRegressor
sg = SGDRegressor(random_state=32)
sg.fit(X_train,y_train)
# Out:
# SGDRegressor(random_state=32)

# %%
pred = sg.predict(X_test)

# %% [markdown]
# ## Q18.

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, pred)
# Out:
# 7.046390481720068e+32

# %%
from sklearn.model_selection import ShuffleSplit

# %%
ss = ShuffleSplit(random_state=32, test_size=0.4, n_splits=8)

# %%
from sklearn.model_selection import cross_validate, cross_val_score

# %%
CVscore=cross_val_score(sg, X_train, y_train, cv=ss)

# %%
max(CVscore),min(CVscore)
# Out:
# (-2.2325557681549474e+33, -6.892224373277545e+34)

# %% [markdown]
# ## Q19.

# %%
np.mean(CVscore)
# Out:
# -2.5172864923258254e+34

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import GridSearchCV

# %%
# ?Pipeline

# %%
# ?PolynomialFeatures

# %%
# ?GridSearchCV

# %%
# ?Lasso

# %%
pipe = Pipeline([('poly', PolynomialFeatures()), ('lasso', Lasso())])

# %%
parameters = {'poly__degree':[1,2,3], 'lasso__alpha':[0.001, 0.0026827, 0.00719686, 0.01930698, 0.05179475, 0.13894955, 0.37275937, 1.0]}

# %%
gsv = GridSearchCV(pipe, parameters, cv=5, scoring='neg_mean_squared_error')

# %%
gsv.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.800e+00, tolerance: 1.739e-03
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.489e+00, tolerance: 1.693e-03
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
np.logspace(-3, 0, num=8)[-1]
# Out:
# 1.0

# %%
gsv.cv_results_.keys()
# Out:
# dict_keys(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time', 'param_lasso__alpha', 'param_poly__degree', 'params', 'split0_test_score', 'split1_test_score', 'split2_test_score', 'split3_test_score', 'split4_test_score', 'mean_test_score', 'std_test_score', 'rank_test_score'])

# %% [markdown]
# ## Q20. & Q21.

# %%
gsv.best_params_
# Out:
# {'lasso__alpha': 0.001, 'poly__degree': 1}

# %%
from sklearn.decomposition import PCA

# %%
# ?PCA

# %%
pca = PCA(n_components=5, svd_solver='full', whiten=True, random_state=32)

# %%
pca.fit(X_train)
# Out:
# PCA(n_components=5, random_state=32, svd_solver='full', whiten=True)

# %%
pcavar = pca.explained_variance_ratio_

# %% [markdown]
# ## Q22.

# %%
sum(pcavar)
# Out:
# 0.9999972466990364

# %%
pca_train = pca.transform(X_train)

# %%
from sklearn.linear_model import RidgeCV

# %%
# ?RidgeCV

# %%
rcv = RidgeCV(alphas=[0.1, 0.01, 1, 0.005]).fit(pca_train, y_train)

# %% [markdown]
# ## Q23.

# %%
rcv_score = rcv.best_score_
rcv_score
# Out:
# -0.030801858477783
